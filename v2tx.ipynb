# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Read the .txt file
v2tx = 'h_v2tx.txt'  # Change this to the path where you saved the .txt file
data = pd.read_csv(v2tx, delimiter=';')  # Adjust delimiter and skiprows based on file format

print(data)
# Out:
#             Date Symbol  Indexvalue
# 0     04.01.1999   V2TX     18.2033
# 1     05.01.1999   V2TX     29.6912
# 2     06.01.1999   V2TX     25.1670
# 3     07.01.1999   V2TX     32.5205
# 4     08.01.1999   V2TX     33.2296
# ...          ...    ...         ...
# 6536  02.09.2024   V2TX     15.4132
# 6537  03.09.2024   V2TX     17.3374
# 6538  04.09.2024   V2TX     19.8665
# 6539  05.09.2024   V2TX     20.0497
# 6540  06.09.2024   V2TX     22.5849
#
# [6541 rows x 3 columns]

# %%
# Save it to Excel
output_path = 'V2TX_Historical_Data.xlsx'
data.to_excel(output_path, index=False)
